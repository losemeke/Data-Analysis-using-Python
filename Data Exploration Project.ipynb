# %% [markdown]
# <a href="https://colab.research.google.com/github/losemeke/Data-Cleaning/blob/main/Data%20Exploration%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Exploration: Cars & CO2 Emissions**

# %%
import pandas as pd

df = pd.read_csv('/content/MY2022 Fuel Consumption Ratings.csv')
df.head()
# Out:
#    Model Year   Make              Model Vehicle Class  Engine Size(L)  \
# 0        2022  Acura                ILX       Compact             2.4
# 1        2022  Acura         MDX SH-AWD    SUV: Small             3.5
# 2        2022  Acura         RDX SH-AWD    SUV: Small             2.0
# 3        2022  Acura  RDX SH-AWD A-SPEC    SUV: Small             2.0
# 4        2022  Acura         TLX SH-AWD       Compact             2.0
#
#    Cylinders Transmission Fuel Type  Fuel Consumption (City (L/100 km)  \
# 0          4          AM8         Z                                9.9
# 1          6         AS10         Z                               12.6
# 2          4         AS10         Z                               11.0
# 3          4         AS10         Z                               11.3
# 4          4         AS10         Z                               11.2
#
#    Fuel Consumption(Hwy (L/100 km))  Fuel Consumption(Comb (L/100 km))  \
# 0                               7.0                                8.6
# 1                               9.4                               11.2
# 2                               8.6                                9.9
# 3                               9.1                               10.3
# 4                               8.0                                9.8
#
#    Fuel Consumption(Comb (mpg))  CO2 Emissions(g/km)  CO2 Rating  Smog Rating
# 0                            33                  200           6            3
# 1                            25                  263           4            5
# 2                            29                  232           5            6
# 3                            27                  242           5            6
# 4                            29                  230           5            7

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 946 entries, 0 to 945
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Model Year                         946 non-null    int64
#  1   Make                               946 non-null    object
#  2   Model                              946 non-null    object
#  3   Vehicle Class                      946 non-null    object
#  4   Engine Size(L)                     946 non-null    float64
#  5   Cylinders                          946 non-null    int64
#  6   Transmission                       946 non-null    object
#  7   Fuel Type                          946 non-null    object
#  8   Fuel Consumption (City (L/100 km)  946 non-null    float64
#  9   Fuel Consumption(Hwy (L/100 km))   946 non-null    float64
#  10  Fuel Consumption(Comb (L/100 km))  946 non-null    float64
#  11  Fuel Consumption(Comb (mpg))       946 non-null    int64
#  12  CO2 Emissions(g/km)                946 non-null    int64
#  13  CO2 Rating                         946 non-null    int64
#  14  Smog Rating                        946 non-null    int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 118.2+ KB

# %% [markdown]
# No missing values and all column data types make sense.

# %%
df.describe()
# Out:
#        Model Year  Engine Size(L)   Cylinders  \
# count       946.0      946.000000  946.000000
# mean       2022.0        3.198732    5.668076
# std           0.0        1.374814    1.932670
# min        2022.0        1.200000    3.000000
# 25%        2022.0        2.000000    4.000000
# 50%        2022.0        3.000000    6.000000
# 75%        2022.0        3.800000    6.000000
# max        2022.0        8.000000   16.000000
#
#        Fuel Consumption (City (L/100 km)  Fuel Consumption(Hwy (L/100 km))  \
# count                         946.000000                        946.000000
# mean                           12.506448                          9.363319
# std                             3.452043                          2.285125
# min                             4.000000                          3.900000
# 25%                            10.200000                          7.700000
# 50%                            12.200000                          9.200000
# 75%                            14.700000                         10.700000
# max                            30.300000                         20.900000
#
#        Fuel Consumption(Comb (L/100 km))  Fuel Consumption(Comb (mpg))  \
# count                         946.000000                    946.000000
# mean                           11.092072                     27.247357
# std                             2.876276                      7.685217
# min                             4.000000                     11.000000
# 25%                             9.100000                     22.000000
# 50%                            10.800000                     26.000000
# 75%                            12.900000                     31.000000
# max                            26.100000                     71.000000
#
#        CO2 Emissions(g/km)  CO2 Rating  Smog Rating
# count           946.000000  946.000000   946.000000
# mean            259.172304    4.539112     4.950317
# std              64.443149    1.471799     1.679842
# min              94.000000    1.000000     1.000000
# 25%             213.250000    3.000000     3.000000
# 50%             257.000000    5.000000     5.000000
# 75%             300.750000    5.000000     6.000000
# max             608.000000   10.000000     7.000000

# %% [markdown]
# The model year is 2022 for every vehicle, so the column can be dropped.

# %%
# Drop model year column
df.drop(['Model Year'], axis=1, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation between variables
cor = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(cor, annot=True)
plt.show()

# %% [markdown]
# CO2 emissions is highly positively correlated to engine size and cylinders: The bigger the engine size and the higher the cylinder value, the higher the CO2 emission. It is also a given that fuel consumption has a very high positive correlation with CO2 emissions.

# %%
# Boxplot of CO2 emissions by vehicle class
plt.figure(figsize=(30,10))
sns.boxplot(x='Vehicle Class', y='CO2 Emissions(g/km)', data=df)
plt.title('CO2 Emissions by Vehicle Class')
plt.show()

# %% [markdown]
# On average, standard SUVs and pickup trucks have higher CO2 emissions than other vehicle classes, while compact cars, on average, have lower CO2 emissions. It also shows that two-seaters have very high outliers.

# %%
# Boxplot of CO2 emissions by vehicle class
plt.figure(figsize=(30,10))
sns.boxplot(x='Transmission', y='CO2 Emissions(g/km)', data=df)
plt.title('CO2 Emissions by Transmission Type')
plt.show()

# %% [markdown]
# A10 transmission tend to be linked to higher CO2 emissions, while AM6 transmission tend to be linked to lower CO2 emissions.

# %%
# Boxplot of CO2 emissions by vehicle class
plt.figure(figsize=(10,10))
sns.boxplot(x='Fuel Type', y='CO2 Emissions(g/km)', data=df)
plt.title('CO2 Emissions by Fuel Type')
plt.show()

# %% [markdown]
# Fuel type E tend to be linked to higher CO2 emissions, followed by fuel type Z, which is also more varied than fuel type E. Fuel type X tend to be linked to lower CO2 emissions.

# %%
# Average CO2 emissions of car makes, sorted from most to least
df.groupby('Make')['CO2 Emissions(g/km)'].mean().sort_values(ascending=False)
# Out:
# Make
# Bugatti          579.333333
# Lamborghini      418.875000
# Rolls-Royce      385.285714
# Bentley          342.875000
# GMC              310.555556
# Dodge            308.761905
# Maserati         307.307692
# Aston Martin     306.400000
# Land Rover       303.000000
# Chevrolet        294.462500
# Ram              289.250000
# Porsche          287.311688
# Jaguar           282.500000
# BMW              276.116667
# Ford             271.426966
# Genesis          266.250000
# Jeep             266.235294
# Chrysler         261.000000
# Infiniti         260.625000
# Cadillac         260.307692
# Lincoln          259.571429
# Audi             251.911111
# Mercedes-Benz    243.511628
# Acura            239.375000
# Alfa Romeo       237.500000
# Lexus            230.071429
# FIAT             221.000000
# Volvo            219.416667
# Buick            217.111111
# Subaru           211.947368
# Volkswagen       210.388889
# Nissan           206.391304
# Toyota           200.803922
# Mazda            198.391304
# Kia              194.200000
# Mitsubishi       193.571429
# MINI             192.400000
# Honda            191.608696
# Hyundai          188.827586
# Name: CO2 Emissions(g/km), dtype: float64

# %% [markdown]
# The top 4 car makes are all super luxury cars, while the bottom 4 are all non-luxury cars. There are only 3 non-luxury car makes in the top 10. For example, GMC, a non-luxury car make, ranks high because they focus on making SUVs and pickup trucks, which are vehicle classes found to have higher CO2 emissions on average.

# %%
# Bar graph of the top 5 highest average engine size of car makes 
esize = df.groupby('Make')['Engine Size(L)'].mean().sort_values(ascending=False).head().plot.barh()
plt.title('Top 5 Car Makes by Average Engine Size')
plt.xlabel('Engine Size(L)')
plt.show()

# %%
# Bar graph of the top 5 highest average cylinder value of car makes 
df.groupby('Make')['Cylinders'].mean().sort_values(ascending=False).head().plot.barh()
plt.title('Top 5 Car Makes by Average Cylinder Value')
plt.xlabel('Cylinder')
plt.show()

# %% [markdown]
# The above two graphs show that super luxury cars tend to have bigger engine sizes and cylinder values. This ties our earlier findings together: (1) engine size and cylinder values are highly positively correlated to CO2 emissions and (2) super luxury cars have the highest CO2 emissions.

# %% [markdown]
# **Conclusion**
#
# If you want to be more eco-friendly with cars released in 2022, then the car to aim for should have the following properties:
# *   Compact
# *   Small engine size
# *  Low cylinder value
# * AM6 transmission
# * Fuel type X
#
# Avoid super luxury cars, SUVs, and pickup trucks.

# %% [markdown]
# # **Activity 1: Line Graph**
#
# A line graph is not the best way to represent our data because our dataset only contains cars that came out in 2022. Since there isn't any trend to explore in out dataset, we opted for a bar graph, instead.

# %%
df2 = df.groupby('Vehicle Class')['CO2 Emissions(g/km)'].mean().sort_values().reset_index()
plt.figure(figsize=(30,10))
plt.bar(df2['Vehicle Class'], df2['CO2 Emissions(g/km)'], color='green')
plt.xticks(rotation = 45)
plt.title('Vehicle Class (of vehicles with model year 2022) vs. Average CO2 Emission (g/km)')
plt.xlabel('Vehicle Class')
plt.ylabel('Average CO2 Emission(g/km)')
plt.show()

# %% [markdown]
# # **Activity 2: Area Plot (New dataset: Total Cancer Deaths by Type)**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

df2 = pd.read_csv('/content/total-cancer-deaths-by-type.csv')
df2.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Liver cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                851
# 1                                                866
# 2                                                890
# 3                                                914
# 4                                                933
#
#    Deaths - Kidney cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                 66
# 1                                                 66
# 2                                                 68
# 3                                                 70
# 4                                                 71
#
#    Deaths - Lip and oral cavity cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                 89
# 1                                                 89
# 2                                                 91
# 3                                                 93
# 4                                                 94
#
#    Deaths - Tracheal, bronchus, and lung cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                983
# 1                                                982
# 2                                                989
# 3                                                995
# 4                                                996
#
#    Deaths - Larynx cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                260
# 1                                                263
# 2                                                268
# 3                                                275
# 4                                                282
#
#    Deaths - Gallbladder and biliary tract cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                180
# 1                                                182
# 2                                                185
# 3                                                189
# 4                                                193
#
#    Deaths - Malignant skin melanoma - Sex: Both - Age: All Ages (Number)  ...  \
# 0                                                 47                      ...
# 1                                                 48                      ...
# 2                                                 51                      ...
# 3                                                 53                      ...
# 4                                                 54                      ...
#
#    Deaths - Brain and central nervous system cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                422
# 1                                                438
# 2                                                472
# 3                                                505
# 4                                                526
#
#    Deaths - Non-Hodgkin lymphoma - Sex: Both - Age: All Ages (Number)  \
# 0                                                996
# 1                                               1010
# 2                                               1040
# 3                                               1062
# 4                                               1069
#
#    Deaths - Pancreatic cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                138
# 1                                                137
# 2                                                137
# 3                                                139
# 4                                                140
#
#    Deaths - Esophageal cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                529
# 1                                                535
# 2                                                546
# 3                                                560
# 4                                                575
#
#    Deaths - Testicular cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    Deaths - Nasopharynx cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                 66
# 1                                                 67
# 2                                                 69
# 3                                                 72
# 4                                                 73
#
#    Deaths - Other pharynx cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                 37
# 1                                                 37
# 2                                                 38
# 3                                                 39
# 4                                                 39
#
#    Deaths - Colon and rectum cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                539
# 1                                                542
# 2                                                550
# 3                                                555
# 4                                                554
#
#    Deaths - Non-melanoma skin cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                 25
# 1                                                 26
# 2                                                 26
# 3                                                 27
# 4                                                 28
#
#    Deaths - Mesothelioma - Sex: Both - Age: All Ages (Number)
# 0                                                  6
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  8
#
# [5 rows x 32 columns]

# %%
# Clean headers
new_col = []
for c in df2.columns:
  if ' - Sex: Both - Age: All Ages (Number)' in c:
    cleaned = c.replace(' - Sex: Both - Age: All Ages (Number)', '')
    new_col.append(cleaned)
  else:
    new_col.append(c)

df2.columns = new_col
df2.head()
# Out:
#         Entity Code  Year  Deaths - Liver cancer  Deaths - Kidney cancer  \
# 0  Afghanistan  AFG  1990                    851                      66
# 1  Afghanistan  AFG  1991                    866                      66
# 2  Afghanistan  AFG  1992                    890                      68
# 3  Afghanistan  AFG  1993                    914                      70
# 4  Afghanistan  AFG  1994                    933                      71
#
#    Deaths - Lip and oral cavity cancer  \
# 0                                   89
# 1                                   89
# 2                                   91
# 3                                   93
# 4                                   94
#
#    Deaths - Tracheal, bronchus, and lung cancer  Deaths - Larynx cancer  \
# 0                                           983                     260
# 1                                           982                     263
# 2                                           989                     268
# 3                                           995                     275
# 4                                           996                     282
#
#    Deaths - Gallbladder and biliary tract cancer  \
# 0                                            180
# 1                                            182
# 2                                            185
# 3                                            189
# 4                                            193
#
#    Deaths - Malignant skin melanoma  ...  \
# 0                                47  ...
# 1                                48  ...
# 2                                51  ...
# 3                                53  ...
# 4                                54  ...
#
#    Deaths - Brain and central nervous system cancer  \
# 0                                               422
# 1                                               438
# 2                                               472
# 3                                               505
# 4                                               526
#
#    Deaths - Non-Hodgkin lymphoma  Deaths - Pancreatic cancer  \
# 0                            996                         138
# 1                           1010                         137
# 2                           1040                         137
# 3                           1062                         139
# 4                           1069                         140
#
#    Deaths - Esophageal cancer  Deaths - Testicular cancer  \
# 0                         529                           3
# 1                         535                           4
# 2                         546                           4
# 3                         560                           5
# 4                         575                           5
#
#    Deaths - Nasopharynx cancer  Deaths - Other pharynx cancer  \
# 0                           66                             37
# 1                           67                             37
# 2                           69                             38
# 3                           72                             39
# 4                           73                             39
#
#    Deaths - Colon and rectum cancer  Deaths - Non-melanoma skin cancer  \
# 0                               539                                 25
# 1                               542                                 26
# 2                               550                                 26
# 3                               555                                 27
# 4                               554                                 28
#
#    Deaths - Mesothelioma
# 0                      6
# 1                      7
# 2                      7
# 3                      7
# 4                      8
#
# [5 rows x 32 columns]

# %%
df2.describe()
# Out:
#               Year  Deaths - Liver cancer  Deaths - Kidney cancer  \
# count  8010.000000            8010.000000             8010.000000
# mean   2004.500000           15941.000624             4610.941199
# std       8.655982           55089.953210            13808.207577
# min    1990.000000               0.000000                0.000000
# 25%    1997.000000              60.000000               21.000000
# 50%    2004.500000             341.500000              147.000000
# 75%    2012.000000            3105.750000             1465.250000
# max    2019.000000          484577.000000           166438.000000
#
#        Deaths - Lip and oral cavity cancer  \
# count                          8010.000000
# mean                           5346.948814
# std                           16321.642622
# min                               0.000000
# 25%                              29.000000
# 50%                             131.000000
# 75%                            1365.250000
# max                          199398.000000
#
#        Deaths - Tracheal, bronchus, and lung cancer  Deaths - Larynx cancer  \
# count                                  8.010000e+03             8010.000000
# mean                                   5.891005e+04             3844.437079
# std                                    1.807509e+05            10907.603041
# min                                    0.000000e+00                0.000000
# 25%                                    2.222500e+02               26.000000
# 50%                                    1.428500e+03              136.500000
# 75%                                    1.425775e+04             1238.500000
# max                                    2.042640e+06           123356.000000
#
#        Deaths - Gallbladder and biliary tract cancer  \
# count                                    8010.000000
# mean                                     4986.568414
# std                                     14733.778028
# min                                         0.000000
# 25%                                        20.000000
# 50%                                       127.000000
# 75%                                      1482.000000
# max                                    172441.000000
#
#        Deaths - Malignant skin melanoma  Deaths - Leukemia  \
# count                       8010.000000        8010.000000
# mean                        1947.733708       11190.691261
# std                         5868.243072       30798.338572
# min                            0.000000           0.000000
# 25%                            8.000000          92.000000
# 50%                           69.000000         494.500000
# 75%                          654.500000        3879.000000
# max                        62844.000000      334592.000000
#
#        Deaths - Hodgkin lymphoma  ...  \
# count                8010.000000  ...
# mean                 1010.150312  ...
# std                  2704.259457  ...
# min                     0.000000  ...
# 25%                     7.000000  ...
# 50%                    46.000000  ...
# 75%                   314.000000  ...
# max                 27839.000000  ...
#
#        Deaths - Brain and central nervous system cancer  \
# count                                       8010.000000
# mean                                        7276.988514
# std                                        20865.059840
# min                                            0.000000
# 25%                                           40.000000
# 50%                                          281.500000
# 75%                                         2292.750000
# max                                       246253.000000
#
#        Deaths - Non-Hodgkin lymphoma  Deaths - Pancreatic cancer  \
# count                    8010.000000                 8010.000000
# mean                     7261.110861                13359.342821
# std                     20605.812531                40695.697306
# min                         0.000000                    0.000000
# 25%                        46.000000                   57.000000
# 50%                       292.000000                  380.500000
# 75%                      2304.500000                 3814.750000
# max                    254614.000000               531107.000000
#
#        Deaths - Esophageal cancer  Deaths - Testicular cancer  \
# count                 8010.000000                 8010.000000
# mean                 16065.139950                  327.085768
# std                  55721.404874                  899.145012
# min                      0.000000                    0.000000
# 25%                     50.000000                    2.000000
# 50%                    366.500000                   12.000000
# 75%                   2851.500000                  126.000000
# max                 498067.000000                10842.000000
#
#        Deaths - Nasopharynx cancer  Deaths - Other pharynx cancer  \
# count                  8010.000000                    8010.000000
# mean                   2253.922222                    2965.132584
# std                    7680.016855                    9942.849790
# min                       0.000000                       0.000000
# 25%                       7.000000                       9.000000
# 50%                      43.000000                      52.000000
# 75%                     450.000000                     589.750000
# max                   71610.000000                  114207.000000
#
#        Deaths - Colon and rectum cancer  Deaths - Non-melanoma skin cancer  \
# count                      8.010000e+03                        8010.000000
# mean                       3.027388e+04                        1434.322472
# std                        8.959821e+04                        4307.364997
# min                        0.000000e+00                           0.000000
# 25%                        1.430000e+02                           7.000000
# 50%                        9.415000e+02                          46.000000
# 75%                        8.856750e+03                         491.000000
# max                        1.085797e+06                       56054.000000
#
#        Deaths - Mesothelioma
# count            8010.000000
# mean              914.333583
# std              2806.910333
# min                 0.000000
# 25%                 3.000000
# 50%                17.000000
# 75%               276.750000
# max             29251.000000
#
# [8 rows x 30 columns]

# %%
# Select for world total death counts 
df2 = df2.loc[df2['Entity'] == 'World']
df2.head()
# Out:
#      Entity      Code  Year  Deaths - Liver cancer  Deaths - Kidney cancer  \
# 7770  World  OWID_WRL  1990                 365215                   72100
# 7771  World  OWID_WRL  1991                 382764                   74404
# 7772  World  OWID_WRL  1992                 399662                   77063
# 7773  World  OWID_WRL  1993                 417329                   80477
# 7774  World  OWID_WRL  1994                 435088                   83173
#
#       Deaths - Lip and oral cavity cancer  \
# 7770                                96628
# 7771                                98834
# 7772                               101317
# 7773                               104920
# 7774                               108120
#
#       Deaths - Tracheal, bronchus, and lung cancer  Deaths - Larynx cancer  \
# 7770                                       1065139                   87459
# 7771                                       1088143                   88942
# 7772                                       1113920                   90438
# 7773                                       1151283                   92949
# 7774                                       1176758                   94573
#
#       Deaths - Gallbladder and biliary tract cancer  \
# 7770                                          94855
# 7771                                          96277
# 7772                                          97868
# 7773                                          99796
# 7774                                         101199
#
#       Deaths - Malignant skin melanoma  ...  \
# 7770                             33083  ...
# 7771                             33917  ...
# 7772                             34917  ...
# 7773                             36352  ...
# 7774                             37489  ...
#
#       Deaths - Brain and central nervous system cancer  \
# 7770                                            139632
# 7771                                            142244
# 7772                                            144947
# 7773                                            148272
# 7774                                            151631
#
#       Deaths - Non-Hodgkin lymphoma  Deaths - Pancreatic cancer  \
# 7770                         126082                      198051
# 7771                         129980                      204106
# 7772                         134170                      210632
# 7773                         139426                      219883
# 7774                         144043                      226459
#
#       Deaths - Esophageal cancer  Deaths - Testicular cancer  \
# 7770                      319332                        7224
# 7771                      327023                        7249
# 7772                      334099                        7294
# 7773                      342837                        7356
# 7774                      348242                        7467
#
#       Deaths - Nasopharynx cancer  Deaths - Other pharynx cancer  \
# 7770                        53459                          51460
# 7771                        54291                          52783
# 7772                        54840                          54209
# 7773                        55436                          56111
# 7774                        55811                          57745
#
#       Deaths - Colon and rectum cancer  Deaths - Non-melanoma skin cancer  \
# 7770                            518126                              23222
# 7771                            529699                              23727
# 7772                            543017                              24364
# 7773                            562393                              25042
# 7774                            575487                              25606
#
#       Deaths - Mesothelioma
# 7770                  15385
# 7771                  15658
# 7772                  15999
# 7773                  16421
# 7774                  16753
#
# [5 rows x 32 columns]

# %%
# Matplotlib
plt.figure(figsize=(15,10))
plt.stackplot(df2['Year'], df2['Deaths - Kidney cancer'], df2['Deaths - Leukemia'], df2['Deaths - Pancreatic cancer'], labels=['Kidney cancer', 'Leukemia', 'Pancreatic cancer'])
plt.title('Deaths from 3 Types of Cancers (1990-2019)')
plt.xlabel('Year')
plt.ylabel('Number of Deaths')
plt.legend(loc='upper left')
plt.ticklabel_format(style = 'plain')
plt.show()

# %%
# Seaborn
sns.set_theme()
plt.figure(figsize=(15,10))
plt.stackplot(df2['Year'], df2['Deaths - Kidney cancer'], df2['Deaths - Leukemia'], df2['Deaths - Pancreatic cancer'], labels=['Kidney cancer', 'Leukemia', 'Pancreatic cancer'])
plt.title('Deaths from 3 Types of Cancers (1990-2019)')
plt.xlabel('Year')
plt.ylabel('Number of Deaths')
plt.legend(loc='upper left')
plt.ticklabel_format(style = 'plain')
plt.show()

# %%
# Plotly (express) 

# Cleaning headers for the restructuring of dataset
new_col2 = []
for c in df2.columns:
  cleaned = c.replace('Deaths - ', '')
  new_col2.append(cleaned)
df2.columns = new_col2

# Restructuring of dataset
melt1 = pd.melt(df2, id_vars='Year', value_vars=df2.columns[3:], var_name='Cancer Type', value_name='Deaths')
melt1.head()
# Out:
#    Year   Cancer Type  Deaths
# 0  1990  Liver cancer  365215
# 1  1991  Liver cancer  382764
# 2  1992  Liver cancer  399662
# 3  1993  Liver cancer  417329
# 4  1994  Liver cancer  435088

# %%
types3 = melt1.loc[melt1['Cancer Type'].isin(['Kidney cancer', 'Leukemia', 'Pancreatic cancer'])]
fig = px.area(types3, x='Year', y='Deaths', color='Cancer Type', title='Deaths from 3 Types of Cancers (1990-2019)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="473412eb-9ebc-486c-8123-012638fb26e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("473412eb-9ebc-486c-8123-012638fb26e2")) {                    Plotly.newPlot(                        "473412eb-9ebc-486c-8123-012638fb26e2",                        [{"hovertemplate":"Cancer Type=Kidney cancer<br>Year=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Kidney cancer","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Kidney cancer","orientation":"v","showlegend":true,"stackgroup":"1","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[72100,74404,77063,80477,83173,85147,86719,88605,91039,94024,97021,99757,103419,107215,110526,114644,117112,120378,124512,127847,131982,135052,138526,141658,144809,149285,152749,156096,161148,166438],"yaxis":"y","type":"scatter"},{"hovertemplate":"Cancer Type=Leukemia<br>Year=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Leukemia","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Leukemia","orientation":"v","showlegend":true,"stackgroup":"1","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[263263,265139,267135,269758,272764,275233,276054,277565,280051,283007,284920,285695,285554,285623,285704,288052,288620,290359,294512,296962,299603,302949,305640,308499,311752,316506,320596,323913,329396,334592],"yaxis":"y","type":"scatter"},{"hovertemplate":"Cancer Type=Pancreatic cancer<br>Year=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Pancreatic cancer","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"Pancreatic cancer","orientation":"v","showlegend":true,"stackgroup":"1","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[198051,204106,210632,219883,226459,231927,236797,242477,249713,258953,268046,277467,288965,300218,310193,323537,333459,346117,360719,374120,389196,402385,416453,429481,443257,459984,474955,489986,510406,531107],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0. ...

# %%
# Graph for all cancer types
fig = px.area(melt1, x='Year', y='Deaths', color='Cancer Type', title='Deaths from Cancer by Type (1990-2019)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0c0f8c30-b7b7-4a79-921d-c3aa24695b31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c0f8c30-b7b7-4a79-921d-c3aa24695b31")) {                    Plotly.newPlot(                        "0c0f8c30-b7b7-4a79-921d-c3aa24695b31",                        [{"hovertemplate":"Cancer Type=Liver cancer<br>Year=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Liver cancer","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Liver cancer","orientation":"v","showlegend":true,"stackgroup":"1","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[365215,382764,399662,417329,435088,450534,462869,469867,476714,480253,470152,444735,409845,381934,363000,358848,361207,366399,376325,381199,386342,391139,398129,408647,422102,436627,449633,460784,471761,484577],"yaxis":"y","type":"scatter"},{"hovertemplate":"Cancer Type=Kidney cancer<br>Year=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Kidney cancer","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Kidney cancer","orientation":"v","showlegend":true,"stackgroup":"1","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[72100,74404,77063,80477,83173,85147,86719,88605,91039,94024,97021,99757,103419,107215,110526,114644,117112,120378,124512,127847,131982,135052,138526,141658,144809,149285,152749,156096,161148,166438],"yaxis":"y","type":"scatter"},{"hovertemplate":"Cancer Type=Lip and oral cavity cancer<br>Year=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Lip and oral cavity cancer","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"Lip and oral cavity cancer","orientation":"v","showlegend":true,"stackgroup":"1","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[96628,98834,101317,104920,108120,110272,112548,115646,117824,120196,123031,125613,128579,131438,133025,137616,140515,144554,149224,152837,157288,161518,166179,170709,174486,179876,184934,188514,193941,199398],"yaxis":"y","type":"scatter"},{"hovertemplate":"Cancer Type=Tracheal, bronchus, and lung cancer<br>Year=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Tracheal, bronchus, and lung cancer","line":{"color":"#ab63fa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Tracheal, bronchus, and lung cancer","orientation":"v","showlegend":true,"stackgroup":"1","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[1065139,1088143,1113920,1151283,1176758,1200039,1215381,1231496,1254538,1287809,1321280,1347965,1383984,1417126,1449142,1485760,1505994,1543830,1590730,1631778,1670745,1704610,1736387,1765970,1799303,1840754,1879226,1920896,1979288,2042640],"yaxis":"y","type":"scatter"},{"hovertemplate":"Cancer Type=Larynx cancer<br>Year=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Larynx cancer","line":{"color":"#FFA15A"},"marker":{"symbol":"circle"},"mode":"lines","name":"Larynx cancer","orientation":"v","showlegend":true,"stackgroup":"1","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[87459,88942,90438,92949,94573,94801,94982,95634,95592,95788,96367,96653,97445,97780,97053,98452,98773,99980,102197,103111,105127,106526,108481,109894,111135,113940,116375,118164,120 ...

# %% [markdown]
# # **Activity 3: Word Clouds**

# %%
df2['Total'] = df2[list(df2.columns[3:])].sum(axis=1)

# %%
df2.head()
# Out:
#      Entity      Code  Year  Liver cancer  Kidney cancer  \
# 7770  World  OWID_WRL  1990        365215          72100
# 7771  World  OWID_WRL  1991        382764          74404
# 7772  World  OWID_WRL  1992        399662          77063
# 7773  World  OWID_WRL  1993        417329          80477
# 7774  World  OWID_WRL  1994        435088          83173
#
#       Lip and oral cavity cancer  Tracheal, bronchus, and lung cancer  \
# 7770                       96628                              1065139
# 7771                       98834                              1088143
# 7772                      101317                              1113920
# 7773                      104920                              1151283
# 7774                      108120                              1176758
#
#       Larynx cancer  Gallbladder and biliary tract cancer  \
# 7770          87459                                 94855
# 7771          88942                                 96277
# 7772          90438                                 97868
# 7773          92949                                 99796
# 7774          94573                                101199
#
#       Malignant skin melanoma  ...  Non-Hodgkin lymphoma  Pancreatic cancer  \
# 7770                    33083  ...                126082             198051
# 7771                    33917  ...                129980             204106
# 7772                    34917  ...                134170             210632
# 7773                    36352  ...                139426             219883
# 7774                    37489  ...                144043             226459
#
#       Esophageal cancer  Testicular cancer  Nasopharynx cancer  \
# 7770             319332               7224               53459
# 7771             327023               7249               54291
# 7772             334099               7294               54840
# 7773             342837               7356               55436
# 7774             348242               7467               55811
#
#       Other pharynx cancer  Colon and rectum cancer  Non-melanoma skin cancer  \
# 7770                 51460                   518126                     23222
# 7771                 52783                   529699                     23727
# 7772                 54209                   543017                     24364
# 7773                 56111                   562393                     25042
# 7774                 57745                   575487                     25606
#
#       Mesothelioma    Total
# 7770         15385  5516590
# 7771         15658  5628289
# 7772         15999  5752640
# 7773         16421  5919156
# 7774         16753  6043965
#
# [5 rows x 33 columns]

# %%
from wordcloud import WordCloud, get_single_color_func

data = dict(zip(melt1['Cancer Type'], melt1['Deaths']))
wc = WordCloud().generate_from_frequencies(data)
plt.figure(figsize=(20,15))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
df3 = pd.read_csv('/content/trump_insult_tweets_2014_to_2021.csv')
df3.head()
# Out:
#    Unnamed: 0        date          target  \
# 0           1  2014-10-09  thomas-frieden
# 1           2  2014-10-09  thomas-frieden
# 2           3  2015-06-16     politicians
# 3           4  2015-06-24      ben-cardin
# 4           5  2015-06-24      neil-young
#
#                                               insult  \
# 0                                               fool
# 1                                               DOPE
# 2                             all talk and no action
# 3  It's politicians like Cardin that have destroy...
# 4                                    total hypocrite
#
#                                                tweet
# 0  Can you believe this fool, Dr. Thomas Frieden ...
# 1  Can you believe this fool, Dr. Thomas Frieden ...
# 2  Big time in U.S. today - MAKE AMERICA GREAT AG...
# 3  Politician @SenatorCardin didn't like that I s...
# 4  For the nonbeliever, here is a photo of @Neily...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10360 entries, 0 to 10359
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10360 non-null  int64
#  1   date        10360 non-null  object
#  2   target      10358 non-null  object
#  3   insult      10360 non-null  object
#  4   tweet       10360 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 404.8+ KB

# %%
text = ' '.join(w for w in df3.insult)
wc2 = WordCloud(collocations = False).generate(text)
plt.figure(figsize=(20,15))
plt.imshow(wc2)
plt.axis('off')
plt.show()
